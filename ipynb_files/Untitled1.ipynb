# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

A = 1
m = 1
g = 9.8
length = 1

dt = 0.01

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
ax1.set_aspect('equal', adjustable='box')
ax2.set_aspect('equal', adjustable='box')

ax1.set(xlim=(-1.5 * A,1.5 * A),ylim=(-1.5* A,1.5 * A))

pen_x, = ax1.plot([], [], 'ko')
rod, = ax1.plot([], [], 'k-')
x = []
y = []

def init():
    x.append(length/np.sqrt(2))
    y.append(-length/np.sqrt(2))
    
    pen_x.set_data(x[0],y[0])
    rod.set_data([0,x[0]],[0,y[0]])
    return pen_x, rod,

def animate(i):
    
    x_disp = x[i]
    y_disp = y[i]
    
    θ = abs(np.arctan(x_disp/y_disp))
    accel = m * g * np.sin(θ)
    
    v_x = accel * np.cos(θ) * dt
    v_y = -accel * np.sin(θ) * dt 
    
    x[i] += v_x * dt
    y[i] -= v_y * dt
    
    x_disp = x[i]
    y_disp = y[i]
    
    θ = abs(np.arctan(x_disp/y_disp))
    
    x.append(length * np.sin(θ))
    y.append(length * np.cos(θ))
    
    pen_x.set_data(x[i],y[i])
    rod.set_data([0,x[i]],[0,y[i]])

    return pen_x, rod, 

anim = FuncAnimation(fig, 
                     animate, 
                     frames=40,
                     init_func = init,
                     interval=100,
                     blit=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

A = 5
m = 1
g = 9.8
length = 1

dt = 0.1

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
ax1.set_aspect('equal', adjustable='box')
ax2.set_aspect('equal', adjustable='box')

ax1.set(xlim=(-1.5 * A,1.5 * A),ylim=(-1.5* A,1.5 * A))

x = [length * np.cos(0)]
y = [-length * np.sin(0)]

v_x = [0]
v_y = [0]

for i in range(10):

    θ = (np.arctan(x[i]/y[i]))
    print(θ)
    
    accel = m * g * np.sin(θ)
    
    a.append(accel)
    
#     v_x.append(v_x[i] + accel * np.sin(θ) * dt)
#     v_y.append(v_y[i] + accel * np.cos(θ) * dt)

    
#     x.append(x[i] + v_x[i] * dt)
#     y.append(y[i] + v_y[i] * dt)
     
#     θ = abs(np.arctan(x[i]/y[i]))
    
#     x.append(length * np.sin(θ))
#     y.append(-length * np.cos(θ))

# ax1.plot(x,y, 'ro')

t = np.linspace(0,1,1)
# print(v_y)
# print(x)

# print(x)

plt.show()
# Out:
# C:\Users\emgle\AppData\Local\Temp\ipykernel_30052\4079316336.py:28: RuntimeWarning: divide by zero encountered in scalar divide
#   θ = (np.arctan(x[i]/y[i]))
# -1.5707963267948966
# 1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# -1.5707963267948966
# [0, -6.000769315822031e-17, 0.0, -6.000769315822031e-17, -1.2001538631644062e-16, -1.8002307947466094e-16, -2.4003077263288124e-16, -3.0003846579110154e-16, -3.6004615894932183e-16, -4.2005385210754213e-16, -4.800615452657625e-16]

# %%
a = []
for i in range(3):
    a.append([i,i])
a
# Out:
# [[0, 0], [1, 1], [2, 2]]
